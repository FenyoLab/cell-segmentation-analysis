# %%
import cell_segmentation as cellseg
import io
import base64
from IPython.display import HTML
from skimage import io as sio
from skimage import exposure
import numpy as np
import os
import matplotlib.pyplot as plt
import ast
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
#dir_ = "/Users/sarahkeegan/fenyolab/data_and_results/pagano/rossi/20171007_S186A-crispr-ebss/WT-ebss-8_R3D_594_xx_435/"
dir_ = "/Users/sarahkeegan/fenyolab/data_and_results/pagano/rossi/20171007_S186A-crispr-ebss/WT-ut-10_R3D_594_xx_435/"

img_to_test = sio.imread(dir_ + 'orig_blue.tif')
sio.imshow(img_to_test)

# %%
from skimage import filters
blur1 = filters.gaussian(img_to_test, sigma=4)
sio.imshow(blur1)
print blur1.dtype
print min(blur1.flatten())
print max(blur1.flatten())
# Out:
# float64
# 0.00711648120857
# 0.928345402302

# %%
th = filters.threshold_otsu(blur1)
sio.imshow(blur1 > th)

# %%
th_img = filters.threshold_adaptive(blur1, block_size=151, method='generic', offset=0, param=filters.threshold_otsu)
sio.imshow(th_img)

# %%
th_img = filters.threshold_adaptive(blur1, block_size=151, method='gaussian', offset=0)
sio.imshow(th_img)

# %%
eq1 = exposure.equalize_hist(img_to_test)
sio.imshow(eq1)
print eq1.dtype
print min(eq1.flatten())
print max(eq1.flatten())
# Out:
# float64
# 3.25520833333e-05
# 1.0

# %%
th = filters.threshold_otsu(eq1)
sio.imshow(eq1 > th)

# %%
cl1 = exposure.equalize_adapthist(img_to_test,kernel_size=512/16, clip_limit=0.005, nbins=2**8)
sio.imshow(cl1)
print cl1.dtype
print min(cl1.flatten())
print max(cl1.flatten())
# Out:
# float64
# 0.0
# 1.0

# %%
th = filters.threshold_otsu(cl1)
sio.imshow(cl1 > th)
